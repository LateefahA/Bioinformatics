# %%
pip install biopython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 27.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from Bio import SeqIO

# %%
filename = "/content/drive/MyDrive/Colab Notebooks/Spolyrhiza_290_v2.protein.fa"

# %%
sequences=[i for i in SeqIO.parse(filename, "fasta")]

# %%
len(sequences)
# Out:
# 19623

# %%
sequence_a=sequences[0]
sequence_a.name
# Out:
# 'Spipo12G0011800'

# %%
gene_of_interest=[]

# %%
for sequence in sequences:
  if sequence.name== 'Spipo12G0011800':
    gene_of_interest.append(sequence)

# %%
len(gene_of_interest)
# Out:
# 1

# %%
for sequence in sequences:
  if sequence.name== 'Spipo12G0011800':
    gene_of_interest=sequence

# %%
gene_of_interest.name
# Out:
# 'Spipo12G0011800'

# %%
SeqIO.write(gene_of_interest, "/content/drive/MyDrive/Colab Notebooks/new.fasta", "fasta")
# Out:
# 1

# %%
sequences_of_interest=["Spipo6G0058200","Spipo11G0028200","Spipo15G0009700","Spipo1G0014700","Spipo0G0138900","Spipo20G0027700","Spipo29G0016400","Spipo17G0023200","Spipo23G0041800","Spipo11G0051700","Spipo6G0064100","Spipo26G0026700","Spipo2G0030200","Spipo0G0090000","Spipo15G0022300","Spipo12G0064700","Spipo28G0010500","Spipo20G0019100","Spipo0G0157400","Spipo1G0096800","Spipo5G0031500","Spipo4G0078000","Spipo10G0047600"]

# %%
#create a function to extract sequence
def extract_sequence(sequence_name):
  gene_of_interest=" "
  for sequence in sequences:
    if sequence.name==sequence_name:
      gene_of_interest=sequence
      return gene_of_interest

# %%
#create a function to extract sequence 2
def extract_sequence2(sequence_name):
  for sequence in sequences:
    if sequence.name==sequence_name:
      return sequence

# %%
genes_of_interest=[]
for gene in sequences_of_interest:
  hit=extract_sequence2(gene)
  genes_of_interest.append(hit)

# %%
len(genes_of_interest)
# Out:
# 23

# %%
SeqIO.write(genes_of_interest, "/content/drive/MyDrive/Colab Notebooks/Dreb_sequences.fasta", "fasta")
# Out:
# 23
